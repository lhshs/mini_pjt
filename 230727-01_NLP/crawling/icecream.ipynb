# %% [markdown]
# # 크롤링

# %%
# 패키지 불러오기
from selenium import webdriver
import pandas as pd
import time
from selenium.webdriver.common.by import By

driver = webdriver.Edge()

# 검색어 입력 및 검색
review_search_url = "https://teacher.i-scream.co.kr/help/afterword/list.do?sso=ok"

driver.get(review_search_url)
driver.get(review_search_url)

# %%
page_click = 1 # 한번 클릭에 10번 넘어가므로 2번 클릭 -> 20페이지
list1 = []


for i in range(page_click):# 내가 설정한 개수만큼 페이지 넘어갈 예정

    for j in range(3, 5): # 한 페이지 넘어갈 때 10개씩 있음(1번은 이전10페이지로)
        for k in range(1, 11): # 한 페이지에 10개씩
            driver.find_element(by='xpath',value = f'//*[@id="content"]/div[3]/table/tbody/tr[{k}]/td[3]/a').click() # 연수후기 페이지 클릭
            name = driver.find_element(by='xpath',value = f'//*[@id="bbs_wrap"]/div/dl[2]/dd/a').text # 연수명
            title = driver.find_element(by='xpath',value = f'//*[@id="bbs_wrap"]/div/dl[1]/dd').text # 연수후기 제목
            el_rated = driver.find_element(by='xpath',value = f'//*[@id="bbs_wrap"]/div/dl[3]/dd[1]/span/span')
            rated = el_rated.get_attribute('class')  # 별점
            review = driver.find_element(by='xpath',value = f'//*[@id="bbs_wrap"]/div/div[1]').text # 내용
            classified = driver.find_element(by='xpath',value = f'//*[@id="bbs_wrap"]/div/dl[3]/dd[2]').text  # 분류
            date = driver.find_element(by='xpath',value = f'//*[@id="bbs_wrap"]/div/dl[4]/dd[2]').text  # 날짜
            
            
  
            
            list1.append([name, title, rated, review, classified, date])
            driver.find_element(by='xpath',value = f'//*[@id="btn-list"]').click() # 목록으로 돌아가기
        driver.find_element(by='xpath',value = f'//*[@id="paging"]/ul/li[{j}]/a').click() # 옆 페이지 넘어가기 ex) 1->2
    driver.find_element(by='xpath',value = f'//*[@id="paging"]/ul/li[12]/a').click() # 다음 페이지 넘어가기 ex) 1->11
    time.sleep(3) # 3초 휴식

# %%
df = pd.DataFrame(list1)
df.rename(columns = {0: 'class', 1: 'title', 2: 'rated', 3: 'comment', 4: 'classified', 5: 'date'})
# Out:
#                             class                                  title  \
# 0              본격! 청개구리 학생심리 사로잡기                                     강추
# 1            가장 쉬운 수업도구, 패들렛과 띵커벨                  패들렛과 띵커벨 활용 잘 할 수 있어요
# 2              신영일과 함께하는 안전교육 365                       필수 연수 부담 없이 편안하게
# 3                최민준&김택수의 위대한 녀석들                    위대한 녀석들 기대를 너무 한 건지
# 4              입시가 뭐니? 대학 입시 찐 전략  지난 2022년 입시에 대한 내용을 주된 내용으로 하는 연수입니다.
# 5   챗GPT 융합교육 가이드, 인공지능(AI) 챗봇 수업    챗GPT 융합교육 가이드, 인공지능(AI) 챗봇 수업 연수 후기
# 6              상식+, 영어로 스마트하게 말하기                             상식을 확실로...
# 7         수업과 성장을 돕는 과정중심평가_초등 기초                     과정중심 평가에 대해 알게되었어요
# 8                     조병영의 문해력 수업                        문해력 강의. 들을만합니다.
# 9             아이들의 내면이 단단해지는 격려수업                                 유익한 연수
# 10     조승연의 비법특강 - 읽기, 쓰기, 공부의 기술                             조승연의 비법 특강
# 11                큰별쌤 최태성의 별★별한국사                        큰별쌤 최태성의 별★별한국사
# 12                유럽여행을 위한 미술 이야기                                흥미로운 연수
# 13         유초등을 사로잡는 감동의 그림책 놀이수업                                 유익한 연수
# 14  챗GPT 융합교육 가이드, 인공지능(AI) 챗봇 수업                                 요즘 트렌트
# 15                 학생을 살리는 학교공간혁신              훌륭한 강사님들을 통한 실제적인 사례 중심으로
# 16                      정재승의 미래학교                               믿고 듣는 연수
# 17                      특수교사 백과사전                                 유익한 연수
# 18                 뭉크씨, 도파민 과잉입니다        교사의 건강한 생활 습관 형성에 도움이 되는 연수입니다.
# 19               최민준&김택수의 위대한 녀석들                    편안하면서도 유익한 내용이었습니다.
#
#               rated                                            comment  \
# 0   star star-rate5  30년 가까이 일하면서도 놓치고 있었던 것들을 알려주었습니다. 그리고 무조건 교사 ...
# 1   star star-rate5  패들렛과 띵커벨 활용하고 있었으나 다양한 교과에 특히 독서 지도에 많이 활용 할 수...
# 2   star star-rate4         안전 연수 올 해 꼭 받아야 하는데, 부담 없이 편안한 마음으로 마쳤어요.~
# 3   star star-rate3  기대를 너무 한 건지 너무 이상적인 내용만 전달하는 것 같습니다.\n교사들의 이해를...
# 4   star star-rate5  지난 2022년 입시에 대한 내용을 주된 내용으로 하는 연수입니다.\n현재 2024...
# 5   star star-rate5  제목을 보고 평소에 많이 들어본 것이라 어떻게 접목을 할 수 있을까 고민을 하다 들...
# 6   star star-rate5                   상식적으로 대충 알고 있는 영어를 확실하게 재정립했습니다.
# 7   star star-rate5                            과정중심 평가에 대해 조금 더 알게되었어요
# 8   star star-rate5  국어 교과는 '국어' 과목 뿐만 아니라 다른 교과에서도 쓰이는 학습 도구의 기능을 ...
# 9   star star-rate5  요즘 부쩍 생활지도의 어려움을 많이 느낀다.\n이번 연수를 통해 다시 한번 그 아이...
# 10  star star-rate5  읽기, 쓰기 강좌는 쉽고 재미있으며 와닿았습니다. 아쉬운 점은 공부 방법이 새로우면...
# 11  star star-rate5  한국사 내용을 체계적으로 들을 수 있어서 좋았지만 내용외에 재미있게 지도하는 지도 ...
# 12  star star-rate5  화가들이 활동한 시대적 배경의 이해를 통해 작품을 이해할 수 있는 의미 있는 연수였...
# 13  star star-rate5              수업에 활용도가 많은 유익하고 좋은 즐거운 연수입니다. 감사합니다~
# 14  star star-rate3  생각보다 빠르게 격변하는 트렌트 환경에 잘 적응할 수 있게 도와주는 연수라 시기 적...
# 15  star star-rate5  훌륭한 강사님들의 실제적인 사례 중심으로 이루어지는 강의가 큰 도움이 되었고, 우리...
# 16  star star-rate5  정재승 교수의 연수라서 오픈되자 마자 신청을 해서 아주 열심히 들었습니다. 너무나 ...
# 17  star star-rate5                                  유익한 연수입니다. 추천합니다.
# 18  star star-rate5  교사의 건강한 생활 습관 형성에 도움이 되는 연수입니다. 더불어 미술작품에 대한 이...
# 19  star star-rate5                                 들을만한 가치가 있는 연수입니다.
#
#    classified        date
# 0        학급경영  2023.07.28
# 1         ICT  2023.07.28
# 2        생활지도  2023.07.27
# 3        생활지도  2023.07.27
# 4        자기계발  2023.07.27
# 5        학습지도  2023.07.27
# 6          어학  2023.07.27
# 7        학습지도  2023.07.27
# 8        학습지도  2023.07.27
# 9        생활지도  2023.07.27
# 10       자기계발  2023.07.27
# 11       교과지도  2023.07.27
# 12       자기계발  2023.07.27
# 13       학습지도  2023.07.27
# 14       학습지도  2023.07.27
# 15       자기계발  2023.07.27
# 16       학습지도  2023.07.26
# 17       학급경영  2023.07.26
# 18       자기계발  2023.07.26
# 19       생활지도  2023.07.26

# %%
df.to_csv('아이스크림 연수후기_20페이지까지.csv')
